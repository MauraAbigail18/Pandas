# %%
#Resampling pada data deret waktu (time series data)
#IMPORT MODULES

import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 1.3.5
# 1.21.6

# %%
#PERSIAPAN DATA FRAME
n_rows = 365*24 #365 merepresentasikan jumlah hari dalam 1 tahun, 24 merepresenrasikan jumlah jam dalam 1 hari
n_cols = 2
cols = ['col 1', 'col 2']
df=pd.DataFrame(np.random.randint(1,20, size=(n_rows,n_cols)), columns = cols)

df.index = pd.util.testing.makeDateIndex(n_rows, freq = 'H')
df
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/__init__.py:15: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing
#                      col 1  col 2
# 2000-01-01 00:00:00      2      6
# 2000-01-01 01:00:00      5     10
# 2000-01-01 02:00:00     18      4
# 2000-01-01 03:00:00     14      3
# 2000-01-01 04:00:00     16     16
# ...                    ...    ...
# 2000-12-30 19:00:00      6     14
# 2000-12-30 20:00:00      4      4
# 2000-12-30 21:00:00     11      8
# 2000-12-30 22:00:00     18     16
# 2000-12-30 23:00:00     11      2
#
# [8760 rows x 2 columns]

# %%
#RESAMPLING DATA DENGAN INTERVAL MONTHLY
df.resample('M')['col 1'].sum().to_frame() #Untuk melakukan resampling berdasarkan bulan
# Out:
#             col 1
# 2000-01-31   7678
# 2000-02-29   6910
# 2000-03-31   7294
# 2000-04-30   7073
# 2000-05-31   7362
# 2000-06-30   6994
# 2000-07-31   7476
# 2000-08-31   7624
# 2000-09-30   7383
# 2000-10-31   7324
# 2000-11-30   7109
# 2000-12-31   6994

# %%
#RESAMPLING DATA DENGAN INTERVAL DAILY
df.resample('D')['col 1'].sum().to_frame() #Untuk melakukan resampling berdasarkan hari
# Out:
#             col 1
# 2000-01-01    265
# 2000-01-02    279
# 2000-01-03    262
# 2000-01-04    289
# 2000-01-05    243
# ...           ...
# 2000-12-26    226
# 2000-12-27    214
# 2000-12-28    199
# 2000-12-29    211
# 2000-12-30    284
#
# [365 rows x 1 columns]

# %%
#MEMBENTUK DATA FRAME DARI DICTIONARY

pd.DataFrame({'col 1' : [1,2,3,4],
              'col 2': [5,6,7,8]})
# Out:
#    col 1  col 2
# 0      1      5
# 1      2      6
# 2      3      7
# 3      4      8

# %%
#MEMBENTUK DATA FRAME DARI NUMPY ARRAY

n_rows = 5
n_cols = 3

arr = np.random.randint(1,20, size=(n_rows,n_cols))
arr
# Out:
# array([[ 1,  1, 10],
#        [16, 18, 12],
#        [ 4,  3, 11],
#        [ 6, 18, 11],
#        [15, 12,  4]])

# %%
pd.DataFrame(arr, columns = tuple('ABC'))
# Out:
#     A   B   C
# 0   1   1  10
# 1  16  18  12
# 2   4   3  11
# 3   6  18  11
# 4  15  12   4

# %%
#MEMBENTUK DATA FRAME DENGAN MEMANFAATKAN pandas.util.testing

pd.util.testing.makeDataFrame().head() #Membuat dummy Data Frame sederhana
# Out:
#                    A         B         C         D
# eqPjvriv9k -0.604228  1.587904 -0.701052  2.199306
# lAgJZcSU0l -1.260116 -0.966639  1.450749  0.296284
# y5ycymKnnn  1.897514 -0.046891 -0.320810 -0.957259
# DAWq61sf75 -0.184496 -0.550070 -0.311691 -1.056753
# aYincLRgMa -0.375340  0.980249 -0.130019 -1.245391

# %%
pd.util.testing.makeMixedDataFrame().head() #Membuat dummy Data Frame yang tipe datanya campur
# Out:
#      A    B     C          D
# 0  0.0  0.0  foo1 2009-01-01
# 1  1.0  1.0  foo2 2009-01-02
# 2  2.0  0.0  foo3 2009-01-05
# 3  3.0  1.0  foo4 2009-01-06
# 4  4.0  0.0  foo5 2009-01-07

# %%
pd.util.testing.makeTimeDataFrame().head() #Membuat dummy Data Frame yang berisi data deret waktu
# Out:
#                    A         B         C         D
# 2000-01-03 -1.860075  1.530315  1.312050 -0.670455
# 2000-01-04  2.300604 -0.194281 -0.808502 -0.128305
# 2000-01-05 -0.187385 -1.113134 -0.047032 -1.132741
# 2000-01-06  2.192057  0.077287  1.123402  0.863645
# 2000-01-07 -0.073766  0.310942  1.339949  0.325597

# %%
pd.util.testing.makeMissingDataframe().head() #Membuat dummy Data Frame yang dengan beberapa missing value yang ditempatkan secara acak
# Out:
#                    A         B         C         D
# 9zPlixKXWM  1.505187  1.070227 -2.085859  0.597905
# qW2JJWxsP6  1.083995 -0.362811  2.607941  0.139788
# SmQSLB2fEK -1.093641       NaN -0.643938 -0.383806
# uaUQc9D5ra       NaN  0.258167 -0.023608  0.914936
# yDyT7a22C5 -0.314293       NaN -0.668133  0.266923

# %%
#PERSIAPAN DATA FRAME

n_rows =5
n_cols= 2

cols = ['omset', 'operasional']
df=pd.DataFrame(np.random.randint(1,20, size=(n_rows,n_cols)), columns = cols)

df
# Out:
#    omset  operasional
# 0      1           12
# 1     15           19
# 2     15            3
# 3     19            3
# 4      9           12

# %%
df['omset'] = df['omset'] *100_000
df['operasional'] = df['operasional'] *10_000
df
# Out:
#      omset  operasional
# 0   100000       120000
# 1  1500000       190000
# 2  1500000        30000
# 3  1900000        30000
# 4   900000       120000

# %%
df.index = pd.util.testing.makeDateIndex(n_rows, freq = 'D')
df = df.reset_index() #Untuk menjadikan indeks saat ini yaitu indeks date time menjadi sebuah kolom biasa dengan nama indeks
df = df.rename(columns = {'index':'tanggal'})
df
# Out:
#      tanggal    omset  operasional
# 0 2000-01-01   100000       120000
# 1 2000-01-02  1500000       190000
# 2 2000-01-03  1500000        30000
# 3 2000-01-04  1900000        30000
# 4 2000-01-05   900000       120000

# %%
#MELAKUKAN FORMATTING TAMPILAN DATA FRAME

formatku = {'tanggal' : '{:%d/%m/%y}', #format hari, bulan, dan tahun
            'operasional' : 'Rp{:.2f}', #untuk meyertakan 2 digit ekstra di belakang koma
            'omset' : 'Rp{:.2f}'}
laporan = df.style.format(formatku)
laporan#MELAKUKAN FORMATTING TAMPILAN DATA FRAME

formatku = {'tanggal' : '{:%d/%m/%y}', #format hari, bulan, dan tahun
            'operasional' : 'Rp{:.2f}', #untuk meyertakan 2 digit ekstra di belakang koma
            'omset' : 'Rp{:.2f}'}
laporan = df.style.format(formatku)
laporan
# Out:
# <style type="text/css">
# </style>
# <table id="T_40b25_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >tanggal</th>
#       <th class="col_heading level0 col1" >omset</th>
#       <th class="col_heading level0 col2" >operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40b25_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_40b25_row0_col0" class="data row0 col0" >01/01/00</td>
#       <td id="T_40b25_row0_col1" class="data row0 col1" >Rp100000.00</td>
#       <td id="T_40b25_row0_col2" class="data row0 col2" >Rp120000.00</td>
#     </tr>
#     <tr>
#       <th id="T_40b25_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_40b25_row1_col0" class="data row1 col0" >02/01/00</td>
#       <td id="T_40b25_row1_col1" class="data row1 col1" >Rp1500000.00</td>
#       <td id="T_40b25_row1_col2" class="data row1 col2" >Rp190000.00</td>
# ...

# %%
type(laporan) #bukan object Data Frame tetapi Styler
# Out:
# pandas.io.formats.style.Styler

# %%
laporan.hide_index() #Untuk menyembunyikan index
# Out:
# <style type="text/css">
# </style>
# <table id="T_40b25_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >tanggal</th>
#       <th class="col_heading level0 col1" >omset</th>
#       <th class="col_heading level0 col2" >operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_40b25_row0_col0" class="data row0 col0" >01/01/00</td>
#       <td id="T_40b25_row0_col1" class="data row0 col1" >Rp100000.00</td>
#       <td id="T_40b25_row0_col2" class="data row0 col2" >Rp120000.00</td>
#     </tr>
#     <tr>
#       <td id="T_40b25_row1_col0" class="data row1 col0" >02/01/00</td>
#       <td id="T_40b25_row1_col1" class="data row1 col1" >Rp1500000.00</td>
#       <td id="T_40b25_row1_col2" class="data row1 col2" >Rp190000.00</td>
#     </tr>
#     <tr>
#       <td id="T_40b25_row2_col0" class="data row2 col0" >03/01/00</td>
#       <td id="T_40b25_row2_col1" class="data row2 col1" >Rp1500000.00</td>
# ...

# %%
laporan.set_caption('Data Omset dan Operasional') #Untuk menambahkan judul
# Out:
# <style type="text/css">
# </style>
# <table id="T_40b25_" class="dataframe">
#   <caption>Data Omset dan Operasional</caption>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >tanggal</th>
#       <th class="col_heading level0 col1" >omset</th>
#       <th class="col_heading level0 col2" >operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_40b25_row0_col0" class="data row0 col0" >01/01/00</td>
#       <td id="T_40b25_row0_col1" class="data row0 col1" >Rp100000.00</td>
#       <td id="T_40b25_row0_col2" class="data row0 col2" >Rp120000.00</td>
#     </tr>
#     <tr>
#       <td id="T_40b25_row1_col0" class="data row1 col0" >02/01/00</td>
#       <td id="T_40b25_row1_col1" class="data row1 col1" >Rp1500000.00</td>
#       <td id="T_40b25_row1_col2" class="data row1 col2" >Rp190000.00</td>
#     </tr>
#     <tr>
#       <td id="T_40b25_row2_col0" class="data row2 col0" >03/01/00</td>
# ...

# %%
laporan.highlight_min('omset', color = 'pink')
laporan.highlight_max('omset', color = 'lightgreen')

laporan.highlight_min('operasional', color = 'lightblue')
laporan.highlight_max('operasional', color = 'grey')
# Out:
# <style type="text/css">
# #T_40b25_row0_col1 {
#   background-color: pink;
# }
# #T_40b25_row1_col2 {
#   background-color: grey;
# }
# #T_40b25_row2_col2, #T_40b25_row3_col2 {
#   background-color: lightblue;
# }
# #T_40b25_row3_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_40b25_" class="dataframe">
#   <caption>Data Omset dan Operasional</caption>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >tanggal</th>
#       <th class="col_heading level0 col1" >omset</th>
#       <th class="col_heading level0 col2" >operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_40b25_row0_col0" class="data row0 col0" >01/01/00</td>
#       <td id="T_40b25_row0_col1" class="data row0 col1" >Rp100000.00</td>
#       <td id="T_40b25_row0_col2" class="data row0 col2" >Rp120000.00</td>
#     </tr>
#     <tr>
#       <td id="T_40b25_row1_col0" class="data row1 col0" >02/01/00</td>
# ...

# %%
#PERSIAPAN DATA FRAME

d1= {'col 1' : [1,2,3],
     'col 2': [10,20,30]}
df1 = pd.DataFrame(d1)
df1
# Out:
#    col 1  col 2
# 0      1     10
# 1      2     20
# 2      3     30

# %%
d2= {'col 3' : [4,5,6],
     'col 4': [40,50,60]}
df2 = pd.DataFrame(d2)
df2
# Out:
#    col 3  col 4
# 0      4     40
# 1      5     50
# 2      6     60

# %%
#Menggabungkan (merge) 2 Data Frame secara berdampingan

df = pd.merge(df1, df2, left_index=True, right_index=True) #penggabungan berdasarkan kolom/berdampingan
df
# Out:
#    col 1  col 2  col 3  col 4
# 0      1     10      4     40
# 1      2     20      5     50
# 2      3     30      6     60
