# %%
#Agregasi pada Pandas Data Frame dengan agg() 
#IMPORT MODULES

import pandas as pd

print(pd.__version__)
# Out:
# 1.3.5

# %%
#PERSIAPAN DATA FRAME
df = pd.read_csv('/content/Iris.csv') #Sebagai Data Frame
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#Mengenal groupby() dan fungsi agregasi
df.groupby('Species')['PetalLengthCm'].count().to_frame() #Untuk menghitung jumlah baris yang ditampilkan sebagai frame
# Out:
#                  PetalLengthCm
# Species
# Iris-setosa                 50
# Iris-versicolor             50
# Iris-virginica              50

# %%
df.groupby('Species')['PetalLengthCm'].mean().to_frame() #Untuk menghitung rata-rata yang ditampilkan sebagai frame
# Out:
#                  PetalLengthCm
# Species
# Iris-setosa              1.464
# Iris-versicolor          4.260
# Iris-virginica           5.552

# %%
df.groupby('Species')['PetalLengthCm'].median().to_frame() #Untuk menghitung nilai tengah yang ditampilkan sebagai frame
# Out:
#                  PetalLengthCm
# Species
# Iris-setosa               1.50
# Iris-versicolor           4.35
# Iris-virginica            5.55

# %%
#Agregasi dengan agg()

df.groupby('Species')['PetalLengthCm'].agg(['count', 'mean', 'median']) #Untuk menggunakan fungsi agregasi secara langsung dan tidak terpisah
# Out:
#                  count   mean  median
# Species
# Iris-setosa         50  1.464    1.50
# Iris-versicolor     50  4.260    4.35
# Iris-virginica      50  5.552    5.55

# %%
df.groupby('Species')['PetalLengthCm'].describe() #Untuk menampilkan deskriptif statistik
# Out:
#                  count   mean       std  min  25%   50%    75%  max
# Species
# Iris-setosa       50.0  1.464  0.173511  1.0  1.4  1.50  1.575  1.9
# Iris-versicolor   50.0  4.260  0.469911  3.0  4.0  4.35  4.600  5.1
# Iris-virginica    50.0  5.552  0.551895  4.5  5.1  5.55  5.875  6.9

# %%
#PERSIAPAN DATA FRAME
df_titanic = pd.read_csv('/content/titanicfull.csv') #Sebagai Data Frame
df_titanic.head() #Untuk menampilkan 5 data pertama saja
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked
# 0  29.00      0      0   24160  211.3375       B5        S
# 1   0.92      1      2  113781  151.5500  C22 C26        S
# 2   2.00      1      2  113781  151.5500  C22 C26        S
# 3  30.00      1      2  113781  151.5500  C22 C26        S
# 4  25.00      1      2  113781  151.5500  C22 C26        S

# %%
#PERSIAPAN DATA FRAME
df_iris = pd.read_csv('/content/Iris.csv') #Sebagai Data Frame 
df_iris.head() #Untuk menampilkan 5 data pertama saja
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#Memantau penggunaan memori suatu Data Frame

df_titanic.info(memory_usage = 'deep') #Untuk memantau penggunaan memori pada data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   survived  1309 non-null   int64
#  2   name      1309 non-null   object
#  3   sex       1309 non-null   object
#  4   age       1046 non-null   float64
#  5   sibsp     1309 non-null   int64
#  6   parch     1309 non-null   int64
#  7   ticket    1309 non-null   object
#  8   fare      1308 non-null   float64
#  9   cabin     295 non-null    object
#  10  embarked  1307 non-null   object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 452.7 KB

# %%
df_iris.info(memory_usage = 'deep') #Untuk memantau penggunaan memori pada data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 16.3 KB

# %%
#Memantau penggunaan memori untuk setiap kolom dari suatu Data Frame
df_titanic.memory_usage(deep=True) #satuannya berupa byte
# Out:
# Index          128
# pclass       10472
# survived     10472
# name        110127
# sex          80781
# age          10472
# sibsp        10472
# parch        10472
# ticket       83502
# fare         10472
# cabin        50366
# embarked     75870
# dtype: int64

# %%
df_iris.memory_usage(deep=True) #satuannya berupa byte
# Out:
# Index              128
# Id                1200
# SepalLengthCm     1200
# SepalWidthCm      1200
# PetalLengthCm     1200
# PetalWidthCm      1200
# Species          10550
# dtype: int64

# %%
#PERSIAPAN DATA FRAME
d = {'kolom_satu' : [1,2,3,4,5],
     'kolom dua' : [10,20,30,40,50]}
df = pd.DataFrame(d)
df
# Out:
#    kolom_satu  kolom dua
# 0           1         10
# 1           2         20
# 2           3         30
# 3           4         40
# 4           5         50

# %%
#Seleksi baris dengan query() 
df.query('kolom_satu > 2') #Untuk mengeksekusi kolom yang tidak mengandung karakter spasi
# Out:
#    kolom_satu  kolom dua
# 2           3         30
# 3           4         40
# 4           5         50

# %%
df.query('`kolom dua` > 30') #Untuk mengeksekusi kolom yang mengandung karakter spasi
# Out:
#    kolom_satu  kolom dua
# 3           4         40
# 4           5         50

# %%
#PERSIAPAN SERIES

s = pd.Series(range(1591683521,1592201921,3600))
s = pd.to_datetime(s, unit ='s') #Untuk mengkonversi Series menjadi date time
s.head()
# Out:
# 0   2020-06-09 06:18:41
# 1   2020-06-09 07:18:41
# 2   2020-06-09 08:18:41
# 3   2020-06-09 09:18:41
# 4   2020-06-09 10:18:41
# dtype: datetime64[ns]

# %%
#Pengaturan zona waktu (time zone)
s = s.dt.tz_localize('UTC') #mengstandarisasi tipe data dengan menggunakan UTC
s.head()
# Out:
# 0   2020-06-09 06:18:41+00:00
# 1   2020-06-09 07:18:41+00:00
# 2   2020-06-09 08:18:41+00:00
# 3   2020-06-09 09:18:41+00:00
# 4   2020-06-09 10:18:41+00:00
# dtype: datetime64[ns, UTC]

# %%
s = s.dt.tz_convert('Asia/Jakarta') #Mengkonversi tipe data dengan local time Asia/Jakarta
s.head()
# Out:
# 0   2020-06-09 13:18:41+07:00
# 1   2020-06-09 14:18:41+07:00
# 2   2020-06-09 15:18:41+07:00
# 3   2020-06-09 16:18:41+07:00
# 4   2020-06-09 17:18:41+07:00
# dtype: datetime64[ns, Asia/Jakarta]

# %%
s = s.dt.tz_convert('Australia/Hobart') #Mengkonversi tipe data dengan local time Australia/Hobart
s.head()
# Out:
# 0   2020-06-09 16:18:41+10:00
# 1   2020-06-09 17:18:41+10:00
# 2   2020-06-09 18:18:41+10:00
# 3   2020-06-09 19:18:41+10:00
# 4   2020-06-09 20:18:41+10:00
# dtype: datetime64[ns, Australia/Hobart]
